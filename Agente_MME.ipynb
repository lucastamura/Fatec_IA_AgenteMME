.24,35.06,34.65,34.2,34.29,34.86,35.03,35.79,36.47,36.16,36.29,36.26,35.25,34.35,35.36,35.4,35.44,35.34,34.02,34.28,34.42,34.36,33.5,33.99,34.06,34.87,34.92,35.4,34.38,33.24,32.98,33.51,33.91,33.07,32.82,34.72,34.75,34.68,34.83,34.83,34.15,35,35.24,35.16,35.22,35.59,35.36,36.23,36.16,34.9,35.11,34.85,33.8,33.85,33.85,33.13,33.48,33.16,32.82,31.64,31.53,31.15,31.5,31.94,32.13,31.9,31.77,31.79,31.94,32.66,33.84,32.86,33.1,34.33,33.83,33.93,33.48,34.82,35.22,36.25,36.39,36.58,36.55,36.74,36.86,37.67,38.17,38.37,38.27,38.34,38.61,38.34,37.7,37.88,37.94,37.08,36.65,37.6,37.33,37.4,39.04,37.71,37.62,37.54,37.39,38.13,38.16,38.06,37.84,36.53,37.41,37.73,37.47,37.43,35.18,35.41,35.51,35.22,35.74,35.54,35.66,36.39,36.17,36.57,36.53,35.16,34.8,34.54,34.5,34.02,34.73,33.77,34.9,34.63,34.52,35.99,35.32,35.66,36.17,36.14,36.68,35.62,36.46,36.57,36.69,36.63,36.65,37.78,37.33,38.26,38.02,38.64,37.35,37.46,37.69,37.67,38.1,38.85,37.83,37.96,37.68,37.57,38.28,37.06,35.88,36.1,36.59,36.06,36.42,37.03,36.79,37.77,36.72,36.79,36.9,36.9,36.37,36.3,35.55,35.56,34.97,34.01,34.28,34.08,34.35,34.29,34.2,33.02,33.33,33.1,32.93,33.39,33.23,33.1,32.24,30.58,31.41,30.27,30.9,32.49,32.52,33.66,33.11,33.91,31.1,30.84,40.86,40.5,40.08,40.23,39.85,39.47,38.32,38.1,38.28,38.12,38.64,39.07,38.14,37.78,37.98,35.66,37.18]

serieHistorica = vale1

# gráfico para visualizar a serie historica
import matplotlib.pyplot as plt
x = [i for i in range(len(serieHistorica))]
y = list(reversed(serieHistorica))



# Função para Média Móvel
def mediasMoveis(serie):
    medias = []
    for i, v in enumerate(serie):
        if i == 0:
            m = v
            medias.append(m)
        else:
            m = m + (v - m) / (i + 1)
            medias.append(m)
    return medias


# Classe do agente
class Agente():
  def __init__(self, estado=None, funcaoAgente=None):
    if funcaoAgente == None:
      def funcaoAgente(*entradas):
        return "Funcao Default"
    self.estado = estado
    self.funcaoAgente = funcaoAgente
    self.historicoPercepcoes = []

  def percepcao(self):
    entrada = input("Digite algo")
    self.historicoPercepcoes.append(eval(entrada))

  def saida(self):
    return self.funcaoAgente(self.historicoPercepcoes)

a = Agente()

a.historicoPercepcoes

# Criar a Classe Ambiente
class Ambiente:
  def __init__(self, estadoInicial = None):
    self.estado = estadoInicial
    self.objetosNoAmbiente = []
    self.agentes = []

  def percepcao(self, agente):
    return None

  def adicionaAgente(self, agente):
    self.agentes.append(agente)

  def adicionaObjeto(self, objeto):
    self.objetosNoAmbiente.append(objeto)

am = Ambiente()
am.adicionaAgente(a)
am.agentes

# Função do Agente
def funcaoAgenteCompraAcao(media, cotacao):
  if cotacao >= media:
    return False, cotacao, media
  else:
    return True, cotacao, media

# Agente que negocia ações
class AgenteNegociador(Agente):
  def __init__(self, estadoInicial=None, funcaoAgente=None):
    super().__init__(estadoInicial, funcaoAgente)
    self.observacoes = 0
    self.mediaAtual = 0
    self.medias = []

  def AtualizaEstado(self, cotacao):
    self.observacoes += 1
    if self.observacoes == 1:
      self.mediaAtual = cotacao
    else:
      self.mediaAtual = self.mediaAtual + (cotacao - self.mediaAtual) / (self.observacoes + 1 )

    self.estado.append(cotacao)
    self.medias.append(self.mediaAtual)

  def percepcao(self, valorAtual):
    self.AtualizaEstado(valorAtual)

  def saida(self):
    return self.funcaoAgente(self.medias[-1], self.estado[-1])

# Tentando o agente negociador
an = AgenteNegociador([],funcaoAgenteCompraAcao)
for i in y[:20]:
  an.percepcao(i)
  print(an.saida(), end='\n')

# Classe do agente com Desempenho
class AgenteNegociadorDesempenho(AgenteNegociador):
  def __init__(self, estadoInicial, funcaoAgente=None, SaldoR=0, SaldoA=0):
    super().__init__(estadoInicial, funcaoAgente)
    self.SaldoReal = SaldoR
    self.SaldoAcao = SaldoA
    self.evolucaoReal = []
    self.evolucaoAcao = []

  ## Ato de Comprar Ações
  def comprar(self):
    if self.SaldoReal > 0:
      self.SaldoAcao += self.SaldoReal / self.estado[-1]
      self.SaldoReal = 0
      self.evolucaoAcao.append(self.SaldoAcao)

  ## Ato de Vender ações
  def vender(self):
    if self.SaldoAcao > 0:
      self.SaldoReal += self.SaldoAcao * self.estado[-1]
      self.SaldoAcao = 0
    self.evolucaoAcao.append(self.SaldoAcao)
    self.evolucaoReal.append(self.SaldoReal)

  def desempenho(self): # calcular o lucro
    return self.evolucaoReal[-1] - self.evolucaoReal[0]

# Ambiente Financeiro
class AmbienteFinanceiro(Ambiente):
  def __init__(self, estadoInicial):
    super().__init__(estadoInicial)

  def percepcao(self, agente): # amb notificar o agente
    for i in self.estado:
      for ag in self.agentes:
        ag.percebe(i)
    return

  def executaAmbiente(self):
    for gst in self.estado:
      for ag in self.agentes:
        ag.AtualizaEstado(gst)
        acaoCompra = ag.saida()
        if acaoCompra[0] == True:
          ag.comprar()
        else:
          ag.vender()

  def desempenhoAgente(self):
    desempenho = []
    for i, ag in enumerate(self.agentes):
      desempenho.append((i, ag.desempenho()))
    return desempenho

# Colocando o agente para trabalhar
ag = AgenteNegociadorDesempenho([], funcaoAgenteCompraAcao, 1000,0)
am = AmbienteFinanceiro(y)
am.adicionaAgente(ag)
am.executaAmbiente()
desempenho = am.desempenhoAgente()
# Out:
# (False, 37.18, 37.18)
# (True, 35.66, 36.67333333333333)
# (False, 37.98, 37.0)
# (False, 37.78, 37.156)
# (False, 38.14, 37.32)
# (False, 39.07, 37.57)
# (False, 38.64, 37.70375)
# (False, 38.12, 37.75)
# (False, 38.28, 37.803)
# (False, 38.1, 37.83)
# (False, 38.32, 37.87083333333333)
# (False, 39.47, 37.99384615384615)
# (False, 39.85, 38.12642857142857)
# (False, 40.23, 38.266666666666666)
# (False, 40.08, 38.379999999999995)
# (False, 40.5, 38.50470588235294)
# (False, 40.86, 38.63555555555555)
# (True, 30.84, 38.22526315789473)
# (True, 31.1, 37.86899999999999)
# (True, 33.91, 37.680476190476185)

# %% [markdown]
# # Modelo de agente MME
#
,38.53,37.72,37.26,37.43,37.37,37.08,37.06,36.69,37.36,36.37,36.66,36.81,37.27,37.01,36.41,35.24,35.06,34.65,34.2,34.29,34.86,35.03,35.79,36.47,36.16,36.29,36.26,35.25,34.35,35.36,35.4,35.44,35.34,34.02,34.28,34.42,34.36,33.5,33.99,34.06,34.87,34.92,35.4,34.38,33.24,32.98,33.51,33.91,33.07,32.82,34.72,34.75,34.68,34.83,34.83,34.15,35,35.24,35.16,35.22,35.59,35.36,36.23,36.16,34.9,35.11,34.85,33.8,33.85,33.85,33.13,33.48,33.16,32.82,31.64,31.53,31.15,31.5,31.94,32.13,31.9,31.77,31.79,31.94,32.66,33.84,32.86,33.1,34.33,33.83,33.93,33.48,34.82,35.22,36.25,36.39,36.58,36.55,36.74,36.86,37.67,38.17,38.37,38.27,38.34,38.61,38.34,37.7,37.88,37.94,37.08,36.65,37.6,37.33,37.4,39.04,37.71,37.62,37.54,37.39,38.13,38.16,38.06,37.84,36.53,37.41,37.73,37.47,37.43,35.18,35.41,35.51,35.22,35.74,35.54,35.66,36.39,36.17,36.57,36.53,35.16,34.8,34.54,34.5,34.02,34.73,33.77,34.9,34.63,34.52,35.99,35.32,35.66,36.17,36.14,36.68,35.62,36.46,36.57,36.69,36.63,36.65,37.78,37.33,38.26,38.02,38.64,37.35,37.46,37.69,37.67,38.1,38.85,37.83,37.96,37.68,37.57,38.28,37.06,35.88,36.1,36.59,36.06,36.42,37.03,36.79,37.77,36.72,36.79,36.9,36.9,36.37,36.3,35.55,35.56,34.97,34.01,34.28,34.08,34.35,34.29,34.2,33.02,33.33,33.1,32.93,33.39,33.23,33.1,32.24,30.58,31.41,30.27,30.9,32.49,32.52,33.66,33.11,33.91,31.1,30.84,40.86,40.5,40.08,40.23,39.85,39.47,38.32,38.1,38.28,38.12,38.64,39.07,38.14,37.78,37.98,35.66,37.18]

serieHistorica = vale3
import matplotlib.pyplot as plt

# Criando um array de contagem de dias da série histórica
x = [i for i in range(len(serieHistorica))]

# Revertendo a série histórica do mais antigo para o mais novo
y = list(reversed(serieHistorica))

# Função para calcular a EMA - Média Móvel Exponencial
def calcularEMA(serie, periodo):
    ema = []
    k = 2 / (periodo + 1)  # Constante de suavização
    for i, v in enumerate(serie):
        if i == 0:
            ema.append(v)  # O primeiro valor da EMA é igual ao primeiro valor da série
        else:
            ema.append((v * k) + (ema[-1] * (1 - k)))
    return ema

# Calculando a EMA longa (60 períodos) e a EMA curta (15 períodos)
ema_longa = calcularEMA(y, 26)
ema_curta = calcularEMA(y, 12)


# Classe do agente negociador
class AgenteNegociador:

    def __init__(self, saldo_inicial):
        self.saldo_real = saldo_inicial  # Saldo inicial em dinheiro
        self.saldo_acao = 0  # Saldo inicial em ações
        self.lucro = 0  # Saldo inicial em ações
        self.evolucao_real = []  # Histórico da evolução do saldo em dinheiro

    # Método para comprar ações
    def comprar(self, cotacao):
        if self.saldo_real > 0:
            self.saldo_acao += self.saldo_real / cotacao  # Converte todo o saldo em dinheiro para ações
            self.saldo_real = 0  # Zera o saldo em dinheiro

    # Método para vender ações
    def vender(self, cotacao):
        if self.saldo_acao > 0:
            self.saldo_real += self.saldo_acao * cotacao  # Converte todas as ações para dinheiro
            self.saldo_acao = 0  # Zera o saldo em ações
            self.lucro = self.saldo_real
        self.evolucao_real.append(self.saldo_real)  # Registra o saldo em dinheiro após a venda

    # Método para executar as operações de compra e venda com base nas EMAs
    def executar(self, cotacoes, ema_curta, ema_longa):
        for i in range(1, len(cotacoes)):
            if ema_curta[i] > ema_longa[i] and ema_curta[i-1] <= ema_longa[i-1]:
                self.comprar(cotacoes[i])  # Compra quando a EMA curta cruza acima da EMA longa
            elif ema_curta[i] < ema_longa[i] and ema_curta[i-1] >= ema_longa[i-1]:
                self.vender(cotacoes[i])  # Vende quando a EMA curta cruza abaixo da EMA longa.
            else:
                if self.saldo_real > 0:
                    self.evolucao_real.append(self.saldo_real)  # Registra o saldo em dinheiro sem alterações
                elif self.saldo_acao > 0 and  self.lucro > 0:
                    self.evolucao_real.append(self.lucro)  # Registra o saldo em dinheiro sem alterações


# Inicializando o agente com saldo inicial de 1000
agente = AgenteNegociador(1000)
agente.executar(y, ema_curta, ema_longa)

# %%
# Plotando gráfico dos valores da cotação da ação da Vale

plt.plot(x,y)
plt.xlabel("Dias")
plt.ylabel("Cotação")
plt.title("VALE3 (2019-2024)")
plt.show()

# %%
# Plotando a visão da média móvel simples

plt.plot(x,y)
plt.plot(x,mediasMoveis(y), label="Media Movel")
plt.xlabel("Dias")
plt.ylabel("Cotação")
plt.title("VALE3 (2019-2024) Média Móvel Simples")
plt.show()

# %%
# Plotando gráfico das cotações e das MME
plt.plot(x, y, label="Cotação")
plt.plot(x, ema_curta, label="Média Móvel Exponencial Curta")
plt.plot(x, ema_longa, label="Média Móvel Exponencial Longa")
plt.xlabel("Dias")
plt.ylabel("Cotação")
plt.title("VALE3 (2019-2024) Média Móvel Exponencial")
plt.legend()
plt.show()

# %%
# Plotando a evolução do saldo do agente MMS
x2 = list(range(len(agente.evolucao_real)))
plt.plot(x2, agente.evolucao_real)
plt.xlabel("Transações")
plt.ylabel("Saldo em Reais")
plt.title("Evolução do agente Média Móvel Simples")
plt.show()
desempenho2 = agente.evolucao_real[-1] - 1000
# Exibindo o desempenho final do agente
print("Desempenho final: ", desempenho2)
# Out:
# Desempenho final:  784.3711028029422

# %%
# Plotando a evolução do saldo do agente MME
x2 = list(range(len(ag.evolucaoReal)))
plt.plot(x2, ag.evolucaoReal)
plt.xlabel("Dias")
plt.ylabel("Saldo em Reais")
plt.title("Evolução do agente Média Móvel Exponencial")
plt.show()
print("Desempenho: ", desempenho)
# Out:
# Desempenho:  [(0, 1010.9588933670725)]

# %%
# Plotando diferença entre as estratégias
x2 = list(range(len(ag.evolucaoReal)))
plt.plot(x2, ag.evolucaoReal)
x3 = list(range(len(agente.evolucao_real)))
plt.plot(x3, agente.evolucao_real)
# x3 = list(range(len(ag.evolucaoAcao)))
# plt.plot(x3, ag.evolucaoAcao)
plt.xlabel("Dias")
plt.ylabel("Saldo em Reais")
plt.title("Evolução dos agentes MMS e MME")
plt.show()

diferenca_desempenho = 1010.9588933670725 - desempenho2
print("Diferença de desempenho (MMS - MME): ", diferenca_desempenho)
# Out:
# Diferença de desempenho (MMS - MME):  226.58779056413027
